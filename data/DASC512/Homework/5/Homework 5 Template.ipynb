# %% [markdown]
# # DASC 512: Homework 5

# %% [markdown]
# # Student Name: *Add Your Name Please*

# %%
# Package imports

# %% [markdown]
# # Problem 1
#
# Using the `hofbatting.csv` file that you've come to know and love, conduct a regression analysis to determine if the On-Base Percentage (OBP) can be used to predict Slugging Percentage (SLG).

# %%
# Import data

# %% [markdown]
# ***
#
# ## 1A
#
# Test whether this model is providing useful information. In other words, is the slope non-zero?
#
# *Note: If we can't conclude that the slope is non-zero, then we also can't conclude that the regression model is better than the model $y=\bar{x}$*

# %%
# Create the model and gather the results for analysis

# %% [markdown]
# ### Answer
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# #### Plots

# %%
# Provide a scatterplot with regression line for your model

# %% [markdown]
# #### Summary
#
# *Is this model useful? How much of the variance in SLG is explained by the linear model on OBP? What does this tell you practically speaking?*
#
# #### Parameter estimates
#
# *Give your parameter estimates from the regression model*
#
# * Intercept: $\hat{b}_0=$
# * Slope: $\hat{b}_1=$
#
# #### Hypothesized model
#
# *Fill in the parameter estimates from your model into its mathematical form*
#
# $\hat{y} = 1.23 + 4.56 x$
#
# #### Coefficient of determination
#
# *Fill in the coefficient of determination value from the regression model*
#
# $R^2 =  $
#
# #### Hypothesis test
#
# #### Hypotheses
# $H_0 : \beta_1 = 0$
#
# $H_a : \beta_1 \neq 0$
#
# #### Test Statistic
# $t = $
#
# #### P-value
# $p$
#
# #### Formal Conclusion

# %% [markdown]
# -----
#
# ## 1B
#
# What is the expected slugging percentage for players with an OBP of 0.32? Give a confidence interval for $\alpha=0.05$.
#
# *Hint: This is the expected percentage for players in general, based on the model in 1A. Is that an estimation interval or a prediction interval?*

# %%
# Gather the point prediction and appropriate interval

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# The expected SLG for players with an OBP of 0.32 is (), with a 95% estimation/prediction (*pick one*) interval of between () and ().

# %% [markdown]
# -----
#
# ## 1C
#
# What would you expect the slugging percentage of a new inductee with an OBP of 0.32 to be? Give a confidence interval for $\alpha=0.05$.
#
# *Hint: This is the expected percentage for one new player, based on the model in 1A. Is that an estimation interval or a prediction interval?*

# %%
# Gather the point prediction and appropriate interval

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# The expected SLG for players with an OBP of 0.32 is (), with a 95% estimation/prediction (*pick one*) interval of between () and ().

# %% [markdown]
# ## 1D
#
# We previously identified Billy Hamilton as a potential outlier. Redo the analysis from 1A, 1B, and 1C excluding his data. Did it make a difference?
#
# Note: To be clear, you wouldn't want to remove outliers for a model unless you had reason to believe that the data point was for some reason invalid. Otherwise, outliers still provide useful information about unlikely outcomes. This exercise is only to explore the effect of an outlier before we talk about influence points (which Billy Hamilton is).

# %%
# Create a DataFrame without Billy Hamilton included and re-run your analysis

# %% [markdown]
# #### Plots

# %%
# Provide a plot to show the change. Be creative.

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# #### Summary
#
# *Is this new model useful? How much variance is explained? How does that differ from the full dataset? What else has changed?*
#
# #### Parameter estimates
#
# * Intercept: $\hat{b}_0 = $
# * Slope: $\hat{b}_1 = $
#
# #### Hypothesized model
#
# $\hat{y} = $
#
# #### Coefficient of determination
#
# $R^2 = $
#
# #### Confidence Intervals
#
# - Estimation interval for $x=0.32$: $()$
# - Prediction interval for $x=0.32$: $()$
#
# #### Hypothesis test
#
# #### Hypotheses
# $H_0 : $
#
# $H_a : $
#
# #### Test Statistic
# $t = $
#
# #### P-value
# $p$
#
# #### Formal Conclusion

# %% [markdown]
# -----
#
# # Problem 2
#
# In baseball, it is hypothesized that we can use the run differential to predict the number of wins a team will have by the end of the season. Use the file `Teams2023.csv` to test this concept.

# %%
# Import the data

# %% [markdown]
# -----
#
# ## 2A
#
# Create a column of data for Run Differential (runs - runs allowed or `R - RA`) and a column for Win Percentage (`W/(W+L)`). Use these values to determine if the Run Differential can be used to predict the percentage of wins a team will end up with.

# %%
# Create the columns

# %%
# Create the model and gather the results for interpretation

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# #### Plots

# %%
# Another scatterplot with regression line

# %% [markdown]
# #### Summary
#
#
#
# #### Parameter estimates
#
# * Intercept:
# * Slope:
#
# #### Hypothesized model
#
# $\hat{y} = $
#
# #### Coefficient of determination
#
# $R^2 = $
#
# #### Hypothesis test
#
# #### Hypotheses
# $H_0 : $
#
# $H_a : $
#
# #### Test Statistic
# $t = $
#
# #### P-value
# $p$
#
# #### Formal Conclusion

# %% [markdown]
# -----
#
# ## 2B
#
# Create a plot showing the confidence intervals for mean estimation and prediction overlaid on the original scatterplot from 2A. Reduce the dot size so that you can see the lines/zones.

# %%
# Vary the x-axis values over the range of Run Differentials, and calculate the confidence intervals for each RD

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %%
# Generate a scatterplot with regression line, estimation interval, and prediction interval.

# %% [markdown]
# ***
#
# ## 2C
#
# Bill James, the godfather of sabermetrics, empirically derived a non-linear formula to estimate winning percentage called the Pythagorean Expectation.
#
# $$ W_{pct} = \frac{R^2}{R^2 + RA^2} $$
# where $R$ is the number of runs earned (`R`) and $RA$ is the number of runs allowed (`RA`).
#
# Create a new variable representing the Pythagorean Expectation. Now use this new column to replace the Run Differential and re-run your analysis.

# %%
# Calculate the PE and add it to the DataFrame

# %%
# Create the model and generate the results for interpretation

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# #### Plots

# %%
# As usual, create a scatterplot with regression line. 
# If you'd like to add the estimation and prediction intervals, it's good habit!

# %% [markdown]
# #### Summary
#
#
#
# #### Parameter estimates
#
# * Intercept: $\hat{b}_0 = $
# * Slope: $\hat{b}_1 = $
#
# #### Hypothesized model
#
# *Fill in the parameter estimates from your model into its mathematical form*
#
# $\hat{y} = $
#
# #### Coefficient of determination
#
# *Fill in the coefficient of determination value from the regression model*
#
# $R^2 = $
#
# #### Hypothesis test
#
# #### Hypotheses
#
# $H_0 : $
#
# $H_a : $
#
# #### Test Statistic
# $t = $
#
# #### P-value
# $p$
#
# #### Formal Conclusion

# %% [markdown]
# ***
#
# ## 2D
#
# The 2001 Seattle Mariners had 116 wins and 46 losses with a +300 Run Differential in the data. Find this row in your data and pretend that it's a new team with identical statistics.
#
# Use both the Run Differential and Pythagorean Expectation models to create confidence intervals for the Win Percentage expected for another team with identical performance to the Mariners.

# %%
# Find the 2001 Mariners row. The information given is enough to help you find it.

# %%
# Generate the appropriate intervals (prediction or estimation?) for each model

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# For the RD model, the *prediction/estimation* (pick one) interval is (). How did it do?
#
# For the PE model, the *prediction/estimation* (pick one) interval is (). How did it do?

# %% [markdown]
# ***
#
# ## 2E
#
# **You may not use Generative AI to help answer this question.**
#
# What are the pros and cons of each of these models (PE and RD)? Which would you rather use? Why and/or in what situations? Use graphical and/or statistical evidence to support your choice.
#
# Think about practical usage as well as statistical accuracy. This should **not** be a dissertation on baseball or sabermetrics; please focus on the practical and statistical application.

# %% [markdown]
# ### Plots

# %%
# What plots might help you compare the relative strengths and weaknesses of each? Think practically.
# Please do not give me a list of plots that might help. Build the plots and use them to argue your point!

# %% [markdown]
# ### Answer
#
# 🟢 *Please place this cell before your final answer in narrative form. You can move cells using the up and down arrows in the toolbar, or highlight the cell and press `x` to cut and `v` to paste.*

# %% [markdown]
# Which would you rather use? Under what conditions? Why? Be sure to explain your reasoning.
