# %% [markdown]
# # DASC 512: Homework 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
theme='dark'

# %%
# Set a Seaborn style as you like. You can see here I use a variable to
# toggle between light mode (for printing) and dark mode (for notebook displays)

def set_style(theme='dark'):
    import seaborn as sns
    if theme == 'dark':
        sns.set_theme(style='ticks', context='notebook', 
                      rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'text.color':'white',
                      'xtick.color':'white', 'ytick.color':'white', 'axes.labelcolor':'white', 'axes.grid':False, 'axes.edgecolor':'white',
                      'boxplot.whiskerprops.color': 'white', 'boxplot.boxprops.color': 'white', 'grid.alpha':0.3})
    else:
        sns.set_theme(style='ticks', context='notebook')
set_style(theme)

# %% [markdown]
# # Dr. Weimer's Solutions Notebook

# %% [markdown]
# # Problem 1
#
# *The Meaning of Life*
#
# In 2021, Pew Research Center conducted a survey of 2,596 adults in the United States (report [here](https://www.pewresearch.org/global/2021/11/18/what-makes-life-meaningful-views-from-17-advanced-economies/)). They asked, "What aspects of your life do you currently find meaningful, fulfilling, or satisfying?" They did not report raw data, but below is a generated dataset based on reported results.
#
# | Topic | Frequency |
# |-------|:---------:|
# | Family | 716 |
# | Friends | 300 |
# | Material Well-being | 265 |
# | Career | 262 |
# | Challenges | 285 |
# | Spirituality | 250 |
# | Society | 210 |
# | Health | 172 |
# | Hobbies | 136 |

# %% [markdown]
# ## 1A
#
# Compute the Relative Frequencies for each response category.

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Add a column to the DataFrame dfFrequencies that contains the relative frequency.
# Display the DataFrame with both columns.

# %% [markdown]
# 🔴
#
# #### Solution

# %%
# Out:
#                  Topic  Frequency  Relative Frequency
# 0               Family        716            0.275809
# 1              Friends        300            0.115562
# 2  Material Well-being        265            0.102080
# 3               Career        262            0.100924
# 4           Challenges        285            0.109784
# 5          Sprituality        250            0.096302
# 6              Society        210            0.080894
# 7               Health        172            0.066256
# 8              Hobbies        136            0.052388

# %% [markdown]
# ## 1B
#
# Construct a bar graph of the Relative Frequencies. It may be formatted however you think works best for this data. Remember you are plotting relative frequency, not frequency.

# %%
# Sort on Frequency. This is a freebie for your knowledge.
dfFrequencies.sort_values(by='Frequency', ascending=False, inplace=True)

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %% [markdown]
# 🔴
#
# #### Solution

# %% [markdown]
# ## 1C
#
# Reporting on these poll results suggested that over half of respondents chose one of the top three topics. Does the data support this conclusion?

# %% [markdown]
# 🟢 *You should answer this question in the Markdown block below. Use the code block as needed.*

# %%
# Code

# %% [markdown]
# *Markdown*

# %%
# Out:
# 0.50115562403698

# %% [markdown]
# # Problem 2
#
# *Board Game Weights*
#
# The file `bgg2022.csv` on Canvas contains a database of every board game on the popular site "Board Game Geek" from 2022. These data can be used to answer the following questions.
#
# Notes:
# - The column `AveRating` gives the average user review score of the game, where 1 is "Awful - defies game description" and 10 is "Outstanding - will always enjoy playing."
# - The column `AveWeight` gives the average user assessment of the "weight" of each game. Weight refers to the overall complexity of the game, not to any weighted average coefficient or any such thing. Weights of 1 correspond to "Light" and weights of 5 correspond to "Heavy."
# - Games with a `AveWeight` value of 0 have not had their weight rated by any users. Those should be removed and ignored for all of this analysis.

# %%
dfGameData = pd.read_csv('bgg2022.csv')

# %% [markdown]
# ## 2A
#
# Create a single box plot for the review scores (`AveRating`) for all games in this dataset. Remember to add a descriptive title and axis labels.

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %% [markdown]
# 🔴
#
# #### Solution

# %% [markdown]
# ## 2B
#
# Based on the above box plot, is the distribution of all game review scores skewed? If so, in what direction?

# %% [markdown]
# 🟢 *You should answer this question in the Markdown block below. Use the code block as needed.*

# %%
# Code

# %% [markdown]
# *Markdown*

# %% [markdown]
# ## 2C
#
# Create Box Plots for the average weight of games by whether it is ranked as a "Family Game" or not. The Box Plots should be on the same axis to facilitate comparison. If `Family Game Rank` is blank (coded as `NaN`), then it is **not** a Family Game.
#
# Games with an `AveWeight` value of 0 have not had their weight rated by any users. These games should be removed and ignored.
#
# I recommend adding a new column to the DataFrame using the function `np.isnan`. If that function applied to `Family Game Rank` evaluates to `False`, then it **is** a Family Game.

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Filter dfGameData to only include games with AveWeight > 0

# %%
# Create new column and map True/False to more descriptive labels.

# %%
# Create Box Plots for this data. I recommend using Seaborn's sns.boxplot() function,
# but you may use any function you like as long as the plots exist on the same axis.

# %% [markdown]
# 🔴
#
# #### Solution

# %% [markdown]
# ## 2D
#
# Based on the box plots above, approximately what percentage of Non-Family games are heavier than 75% of Family games?

# %% [markdown]
# 🟢 *You should answer this question in the Markdown block below. Use the code block as needed.*

# %%
# Code

# %% [markdown]
# *Markdown*

# %% [markdown]
# 50%

# %% [markdown]
# # Problem 3
#
# *Baseball Hall-of-Famers*
#
# Baseball Hall-of-Famers (HoF) played during different eras of baseball. One common classification of eras (see [here](https://thesportjournal.org/article/examining-perceptions-of-baseballs-eras/)) is the following:
# | Era | Years |
# |-----|:----:|
# | 19th Century |  - 1900 |
# | Dead Ball | 1901 - 1919 |
# | Live Ball | 1920 - 1941 |
# | Integration | 1942 - 1960 |
# | Expansion | 1961 - 1976 |
# | Free Agency | 1977 - 1993 |
# | Steroid Era | 1994 - 2005 |
# | Post-Steroid Era | 2006 - Present |
#
# For this exercise, define the era of a player based on the mid-point of their career (**rounding up if the mid-point falls between eras**).
#
# Using the file `hofbatting.csv` containing non-pitching HoFs as of 2024, classify each player according to their era to answer the following questions.

# %% [markdown]
# ## 3A
#
# Create a Bar Graph for the number of HoFs from each era as of 2024.

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Import the CSV (See Problem 2 for an example)

# %%
# Create a column of data to define the mid-career year.

# %%
# Create a column of data to define the mid-career era, rounding the mid-career year up as needed.

# %%
# Create the graph, being sure to label axes and provide a descriptive title.
# For interpretability, sort the eras chronologically.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %% [markdown]
# ## 3B
#
# One era of baseball should stand out as having produced far more Hall-of-Famers than the rest. Which era is it?

# %% [markdown]
# 🟢 *You should answer this question in the Markdown block below. Use the code block as needed.*

# %%
# Code

# %% [markdown]
# *Markdown*

# %% [markdown]
# ## 3C
#
# Create a Histogram showing the distribution of non-pitching HoFs' Mid-Career year. Set bins by decade, i.e., [1880,1890), [1890,1900), ..., [2010,2020).

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Create the histogram, with mid-career year on the x-axis and the number of HoFs on the y-axis. 
# It should look similar to, but not identical to, the graph in 3A.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %% [markdown]
# ## 3D
#
# There are two major dimensions to hitting: the ability to get on base (measured by the on-base percentage `OBP`) and the ability to advance runners already on base (measured by the slugging percentage `SLG`). Create a scatterplot of OBP (x-axis) vs. SLG (y-axis).

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Create the scatterplot with OBP on the x-axis and SLG on the y-axis.
# Don't forget your title and axis labels.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %% [markdown]
# ## 3E
#
# In the scatterplot above, are there any outliers? If so, identify them by name.
#
# Don't be concerned about any specific ``rule'' for finding outliers; just take notice of any points that seem unusual or fall far from the center of mass for this bivariate distribution.
#
# Specifically, what is the name of the individual represented by the point in the bottom-right with lower SLG than would be expected given his OBP (or conversely higher OBP than would be expected given his SLG)?

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Identify the outlier data points, and specifically the one in the bottom-right.

# %%
# For an added optional challenge, annotate the scatterplot with the names of the outliers.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %%
# Out:
#                Name    OBP    SLG
# 0         Babe Ruth  0.474  0.690
# 47   Billy Hamilton  0.455  0.432
# 56     Ted Williams  0.482  0.634
# 71      Josh Gibson  0.458  0.718
# 88      Ernie Banks  0.330  0.500
# 159    Andre Dawson  0.323  0.482

# %% [markdown]
# ## 3F
#
# Consider a combined metric for hitting: the On-Base Plus Slugging `OPS` statistic, which is a sum of OBP and SLG. Standardize the data (i.e., calculate the *z*-scores), then create a scatterplot with Standardized OPS on the y-axis and Mid-Career Year on the x-axis.

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# Create a column of standardized OPS. Note that OPS is already in the DataFrame.

# %%
# Create the requested scatterplot with Mid-Career Year on the x-axis and 
# standardized OPS on the y-axis.
# Remember titles and axis labels.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %% [markdown]
# ## 3G
#
# A common rule of thumb for identifying possible outliers is an absolute standardized value greater than 3. Which Hall-of-Famers fall into this category, showing unusually high batting prowess as measured by OPS?

# %% [markdown]
# 🟢 **Show your solution code below this block**

# %%
# For any additional (optional) challenge, annotate the scatterplot with their names.

# %% [markdown]
# 🔴
#
# #### Solution
# For the homework sets, I'm experimenting with providing some or all of the solution output so that you know what you're aiming for. Plots do not need to be identical, but should give the same information. You will still need to (1) replicate the results below with your own code above, and (2) interpret the results to answer the questions on the turn-in page.
#
# **Do not run the cell below, or you will lose the solution.**

# %% [markdown]
# # Congratulations on reaching the end of Homework 1!

# %%
sns.dogplot()
